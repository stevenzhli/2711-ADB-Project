# %%
import pandas as pd, numpy as np
import random

# %%
in_file = "./raw/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv"

sample_options = {
    "50k":["./raw/sample50k.csv",50000],
    "500k":["./raw/sample500k.csv", 500000],
    "1kk":["./raw/sample1kk.csv", 1000000],
    "5kk":["./raw/sample5kk.csv", 5000000],
}

sample_file = sample_options["5kk"][0]
sample_size = sample_options["5kk"][1]

# %%
## use shuf to generate samples before import (install `coreutils`, `gshuf` in macos)
#!head -n1 $in_file > $sample_file # get the header
#!gshuf -n $sample_size $in_file >> $sample_file

# %%
sample_file = "./raw/sample5kk.csv"
my_df = pd.read_csv(sample_file, header=0, nrows=1000)
my_df.shape
# Out:
# (1000, 19)

# %%
my_df.head()
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2021-12        MI               26     OCEANA           26127.0
# 1    2022-01        IL               17   FRANKLIN           17055.0
# 2    2022-01        MA               25      ESSEX           25009.0
# 3    2022-01        GA               13     FULTON           13121.0
# 4    2021-07        FL               12       POLK           12105.0
#
#         age_group     sex     race            ethnicity  \
# 0  18 to 49 years    Male    White  Non-Hispanic/Latino
# 1  50 to 64 years  Female  Missing              Missing
# 2  18 to 49 years  Female      NaN                  NaN
# 3  18 to 49 years    Male    White  Non-Hispanic/Latino
# 4  18 to 49 years  Female    White      Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              NaN                  NaN  Missing     Missing
# 1                              NaN                  0.0  Missing     Missing
# 2                              NaN                  NaN  Missing     Missing
# 3                              NaN                  0.0  Missing     Missing
# 4                              NaN                  NaN  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Missing  Missing  Missing  Unknown
# 1  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 2  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
# count rows that do not contain missing values
my_df.dropna().shape[0]
# Out:
# 96750

# %%
# count ratio of missing values in each col
my_df.isna().sum()/my_df.shape[0]
# Out:
# case_month                         0.000000
# res_state                          0.000016
# state_fips_code                    0.000016
# res_county                         0.067335
# county_fips_code                   0.067335
# age_group                          0.019734
# sex                                0.039485
# race                               0.369996
# ethnicity                          0.432406
# case_positive_specimen_interval    0.642981
# case_onset_interval                0.585819
# process                            0.961552
# exposure_yn                        0.947470
# current_status                     0.000000
# symptom_status                     0.607779
# hosp_yn                            0.611965
# icu_yn                             0.963516
# death_yn                           0.672541
# underlying_conditions_yn           0.958144
# dtype: float64

# %%
# examine cols for data distribution
# list of cols with factor values
ls_cols = ["case_month","res_state","age_group","sex","race","ethnicity","exposure_yn","current_status","symptom_status","hosp_yn","icu_yn","death_yn","underlying_conditions_yn"]
# generate the col value count
for col in ls_cols:
    print("\n==== " + col + " ====")
    print(my_df[col].value_counts(dropna=False))
# Out:
# ==== case_month ====
# 2022-01    1108488
# 2021-12     471912
# 2020-12     434382
# 2021-01     367371
# 2020-11     327749
# 2021-08     274025
# 2021-09     258084
# 2021-11     186011
# 2021-10     171834
# 2020-10     153727
# 2021-03     142504
# 2021-02     142109
# 2021-04     120131
# 2020-07     119141
# 2022-02     110567
# 2021-07     105218
# 2020-08      91866
# 2020-09      88523
# 2020-06      79084
# 2021-05      66127
# 2020-04      62305
# 2020-05      56013
# 2021-06      32632
# 2020-03      29506
# 2020-02        347
# 2020-01        344
# Name: case_month, dtype: int64
#
# ==== res_state ====
# CA     701022
# NY     385673
# FL     259356
# IL     239351
# PA     215743
# OH     208125
# NC     201568
# NJ     172286
# GA     161698
# TN     155540
# AZ     152058
# IN     133606
# MA     131286
# SC     115332
# WA     111241
# MN     111063
# VA     110486
# MO     110158
# MI     104377
# CO     103078
# AL      99494
# LA      91072
# WI      79340
# TX      66927
# AR      63942
# KS      60650
# UT      58518
# OR      53834
# OK      52721
# MD      52210
# KY      49412
# NV      48070
# IA      39622
# NM      38436
# CT      30993
# ID      26945
# NE      22259
# DE      19659
# MT      19513
# ND      18651
# AK      18049
# SD      15779
# ME      15430
# RI      15226
# WY      12220
# DC      10562
# HI       8711
# NH       7480
# VT       7439
# PR       4805
# MS       4549
# GU       2215
# VI       1322
# WV        820
# NaN        78
# Name: res_state, dtype: int64
#
# ==== age_group ====
# 18 to 49 years    2588934
# 50 to 64 years     891430
# 0 - 17 years       862932
# 65+ years          558036
# NaN                 98668
# Name: age_group, dtype: int64
#
# ==== sex ====
# Female    2547897
# Male      2254611
# NaN        197427
# Other          65
# Name: sex, dtype: int64
#
# ==== race ====
# White                                     2395265
# NaN                                       1849981
# Black                                      473019
# Asian                                      134552
# Multiple/Other                             103651
# American Indian/Alaska Native               35751
# Native Hawaiian/Other Pacific Islander       7781
# Name: race, dtype: int64
#
# ==== ethnicity ====
# Non-Hispanic/Latino    2398549
# NaN                    2162028
# Hispanic/Latino         439423
# Name: ethnicity, dtype: int64
#
# ==== exposure_yn ====
# NaN    4737348
# Yes     262652
# Name: exposure_yn, dtype: int64
#
# ==== current_status ====
# Laboratory-confirmed case    4283796
# Probable Case                 716204
# Name: current_status, dtype: int64
#
# ==== symptom_status ====
# NaN             3038896
# Symptomatic     1892830
# Asymptomatic      68274
# Name: symptom_status, dtype: int64
#
# ==== hosp_yn ====
# NaN    3059825
# No     1770920
# Yes     169255
# Name: hosp_yn, dtype: int64
#
# ==== icu_yn ====
# NaN    4817578
# No      168901
# Yes      13521
# Name: icu_yn, dtype: int64
#
# ==== death_yn ====
# NaN    3362704
# No     1604744
# Yes      32552
# Name: death_yn, dtype: int64
#
# ==== underlying_conditions_yn ====
# NaN    4790719
# Yes     205814
# No        3467
# Name: underlying_conditions_yn, dtype: int64

# %%
my_df.dtypes
# Out:
# case_month                          object
# res_state                           object
# state_fips_code                    float64
# res_county                          object
# county_fips_code                   float64
# age_group                           object
# sex                                 object
# race                                object
# ethnicity                           object
# case_positive_specimen_interval    float64
# case_onset_interval                float64
# process                             object
# exposure_yn                         object
# current_status                      object
# symptom_status                      object
# hosp_yn                             object
# icu_yn                              object
# death_yn                            object
# underlying_conditions_yn            object
# dtype: object

# %%
# check for special cases of na values
# state not null, county is null
my_df[(my_df["res_county"].isnull()) & (my_df["res_state"].notnull())]
# Out:
#         case_month res_state  state_fips_code res_county  county_fips_code  \
# 21         2022-01        AL              1.0        NaN               NaN
# 40         2020-07        MO             29.0        NaN               NaN
# 57         2021-09        OH             39.0        NaN               NaN
# 64         2022-01        HI             15.0        NaN               NaN
# 68         2020-06        AL              1.0        NaN               NaN
# ...            ...       ...              ...        ...               ...
# 4999917    2020-05        VA             51.0        NaN               NaN
# 4999923    2022-01        ND             38.0        NaN               NaN
# 4999966    2020-07        NJ             34.0        NaN               NaN
# 4999969    2021-09        MO             29.0        NaN               NaN
# 4999999    2022-01        TX             48.0        NaN               NaN
#
#               age_group     sex   race            ethnicity  \
# 21                  NaN    Male    NaN                  NaN
# 40       50 to 64 years    Male  White  Non-Hispanic/Latino
# 57       18 to 49 years    Male  White  Non-Hispanic/Latino
# 64       18 to 49 years    Male  Asian                  NaN
# 68       50 to 64 years     NaN    NaN                  NaN
# ...                 ...     ...    ...                  ...
# 4999917  18 to 49 years    Male  Black  Non-Hispanic/Latino
# 4999923  18 to 49 years  Female  White                  NaN
# 4999966  50 to 64 years  Female  White                  NaN
# 4999969  18 to 49 years  Female    NaN                  NaN
# 4999999  18 to 49 years  Female  White      Hispanic/Latino
#
#          case_positive_specimen_interval  case_onset_interval  \
# 21                                   NaN                  NaN
# 40                                   0.0                  NaN
# 57                                   0.0                  0.0
# 64                                   NaN                  NaN
# 68                                   NaN                  0.0
# ...                                  ...                  ...
# 4999917                              NaN                  NaN
# 4999923                              NaN                  0.0
# 4999966                              NaN                  NaN
# 4999969                              0.0                  NaN
# 4999999                              NaN                  NaN
#
#                      process exposure_yn             current_status  \
# 21                       NaN         NaN  Laboratory-confirmed case
# 40                       NaN         NaN  Laboratory-confirmed case
# 57       Clinical evaluation         NaN  Laboratory-confirmed case
# 64                       NaN         NaN  Laboratory-confirmed case
# 68                       NaN         NaN  Laboratory-confirmed case
# ...                      ...         ...                        ...
# 4999917                  NaN         NaN  Laboratory-confirmed case
# 4999923                  NaN         NaN              Probable Case
# 4999966                  NaN         NaN  Laboratory-confirmed case
# 4999969                  NaN         NaN  Laboratory-confirmed case
# 4999999                  NaN         NaN  Laboratory-confirmed case
#
#         symptom_status hosp_yn icu_yn death_yn underlying_conditions_yn
# 21                 NaN     NaN    NaN      NaN                      NaN
# 40                 NaN     NaN    NaN      NaN                      NaN
# 57         Symptomatic      No    NaN       No                      Yes
# 64                 NaN     NaN    NaN      NaN                      NaN
# 68         Symptomatic      No    NaN      NaN                      NaN
# ...                ...     ...    ...      ...                      ...
# 4999917            NaN     NaN    NaN      NaN                      NaN
# 4999923    Symptomatic     NaN    NaN      NaN                      NaN
# 4999966            NaN     NaN    NaN       No                      NaN
# 4999969            NaN     NaN    NaN      NaN                      NaN
# 4999999            NaN     NaN    NaN      NaN                      NaN
#
# [336595 rows x 19 columns]

# %%
my_df[(my_df["county_fips_code"].isnull()) & (my_df["res_county"].notnull())]
# Out:
# Empty DataFrame
# Columns: [case_month, res_state, state_fips_code, res_county, county_fips_code, age_group, sex, race, ethnicity, case_positive_specimen_interval, case_onset_interval, process, exposure_yn, current_status, symptom_status, hosp_yn, icu_yn, death_yn, underlying_conditions_yn]
# Index: []

# %%
my_df[(my_df["state_fips_code"].isnull()) & (my_df["res_state"].notnull())]
# Out:
# Empty DataFrame
# Columns: [case_month, res_state, state_fips_code, res_county, county_fips_code, age_group, sex, race, ethnicity, case_positive_specimen_interval, case_onset_interval, process, exposure_yn, current_status, symptom_status, hosp_yn, icu_yn, death_yn, underlying_conditions_yn]
# Index: []

# %%
my_df[(my_df["race"]!="White") & (my_df["race"].notnull()) & (my_df["ethnicity"]=="Hispanic/Latino")]
# Out:
#         case_month res_state  state_fips_code      res_county  \
# 718        2022-01        MA             25.0         BRISTOL
# 963        2021-01        FL             12.0          ORANGE
# 1194       2021-01        NY             36.0          QUEENS
# 1279       2021-12        IL             17.0            COOK
# 1301       2021-01        NC             37.0     MECKLENBURG
# ...            ...       ...              ...             ...
# 4998650    2021-12        NY             36.0           BRONX
# 4999072    2022-01        CA              6.0       RIVERSIDE
# 4999341    2021-08        NY             36.0        NEW YORK
# 4999405    2022-01        CA              6.0  SAN BERNARDINO
# 4999745    2022-01        CA              6.0    CONTRA COSTA
#
#          county_fips_code       age_group     sex  \
# 718               25005.0    0 - 17 years  Female
# 963               12095.0  18 to 49 years  Female
# 1194              36081.0    0 - 17 years    Male
# 1279              17031.0  50 to 64 years  Female
# 1301              37119.0    0 - 17 years  Female
# ...                   ...             ...     ...
# 4998650           36005.0  18 to 49 years  Female
# 4999072            6065.0  18 to 49 years    Male
# 4999341           36061.0  18 to 49 years  Female
# 4999405            6071.0    0 - 17 years  Female
# 4999745            6013.0  18 to 49 years  Female
#
#                                   race        ethnicity  \
# 718                              Black  Hispanic/Latino
# 963                              Black  Hispanic/Latino
# 1194                             Black  Hispanic/Latino
# 1279                             Black  Hispanic/Latino
# 1301     American Indian/Alaska Native  Hispanic/Latino
# ...                                ...              ...
# 4998650                          Black  Hispanic/Latino
# 4999072  American Indian/Alaska Native  Hispanic/Latino
# 4999341                          Black  Hispanic/Latino
# 4999405                          Asian  Hispanic/Latino
# 4999745                          Black  Hispanic/Latino
#
#          case_positive_specimen_interval  case_onset_interval process  \
# 718                                  NaN                  NaN     NaN
# 963                                  NaN                  0.0     NaN
# 1194                                 0.0                  NaN     NaN
# 1279                                 NaN                  0.0     NaN
# 1301                                 0.0                  NaN     NaN
# ...                                  ...                  ...     ...
# 4998650                              0.0                  NaN     NaN
# 4999072                              NaN                  NaN     NaN
# 4999341                              0.0                  NaN     NaN
# 4999405                              NaN                  NaN     NaN
# 4999745                              NaN                  NaN     NaN
#
#         exposure_yn             current_status symptom_status hosp_yn icu_yn  \
# 718             NaN              Probable Case            NaN     NaN    NaN
# 963             NaN  Laboratory-confirmed case    Symptomatic      No    NaN
# 1194            NaN  Laboratory-confirmed case   Asymptomatic     NaN    NaN
# 1279            NaN  Laboratory-confirmed case            NaN     NaN    NaN
# 1301            NaN  Laboratory-confirmed case            NaN     NaN    NaN
# ...             ...                        ...            ...     ...    ...
# 4998650         NaN              Probable Case            NaN     NaN    NaN
# 4999072         NaN  Laboratory-confirmed case            NaN     NaN    NaN
# 4999341         NaN  Laboratory-confirmed case   Asymptomatic     NaN    NaN
# 4999405         NaN  Laboratory-confirmed case            NaN     NaN    NaN
# 4999745         NaN  Laboratory-confirmed case            NaN     NaN    NaN
#
#         death_yn underlying_conditions_yn
# 718          NaN                      NaN
# 963          NaN                      NaN
# 1194         NaN                      NaN
# 1279         NaN                      NaN
# 1301          No                      NaN
# ...          ...                      ...
# 4998650      NaN                      NaN
# 4999072      NaN                      NaN
# 4999341      NaN                      NaN
# 4999405      NaN                      NaN
# 4999745      NaN                      NaN
#
# [26715 rows x 19 columns]

# %%
my_df.isna().sum()
# Out:
# case_month                               0
# res_state                               78
# state_fips_code                         78
# res_county                          336673
# county_fips_code                    336673
# age_group                            98668
# sex                                 197427
# race                               1849981
# ethnicity                          2162028
# case_positive_specimen_interval    3214903
# case_onset_interval                2929095
# process                            4807761
# exposure_yn                        4737348
# current_status                           0
# symptom_status                     3038896
# hosp_yn                            3059825
# icu_yn                             4817578
# death_yn                           3362704
# underlying_conditions_yn           4790719
# dtype: int64

# %%
my_df[(my_df["res_state"].isnull()) & (my_df["res_county"].notnull())]
# Out:
# Empty DataFrame
# Columns: [case_month, res_state, state_fips_code, res_county, county_fips_code, age_group, sex, race, ethnicity, case_positive_specimen_interval, case_onset_interval, process, exposure_yn, current_status, symptom_status, hosp_yn, icu_yn, death_yn, underlying_conditions_yn]
# Index: []
